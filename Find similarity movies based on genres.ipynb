# %%
# Import modules
import numpy as np
import pandas as pd
import nltk

# Set seed for reproducibility
np.random.seed(5)
#movies_df = pd.read_csv('movies.csv', sep=',', encoding='latin-1')
movies_df = pd.read_csv("movies.csv", sep=',', encoding="ISO-8859-1")


print("Number of movies loaded: %s " % (len(movies_df)))

# Display the data
movies_df
# Out:
# Number of movies loaded: 1958
#                                                    rank  \
# 0                                                     0
# 1                         Shortly before Christmas 1945
# 2              Despite a clampdown from the authorities
# 3                           Devastated by Sonny's death
# 4       With his father at the end of his career and...
# ...                                                 ...
# 1953                  In the early days of World War II
# 1954    Cohan and his sister join the family act as ...
# 1955                                As his star ascends
# 1956                                      Cohan retires
# 1957                                                  "
#
#                                                   title  \
# 0                                         The Godfather
# 1               drug baron Virgil ""The Turk"" Sollozzo
# 2      the Five Families erupt in open warfare and t...
# 3      Vito decides to end the feuds. Realising that...
# 4                 Michael takes the reins of the family
# ...                                                 ...
# 1953   Cohan comes out of retirement to star as Pres...
# 1954   and soon The Four Cohans are performing succe...
# 1955   he persuades his now struggling parents to jo...
# 1956             but returns to the stage several times
# 1957                                                NaN
#
#                                                   genre  \
# 0                                [u' Crime', u' Drama']
# 1                       backed by the Corleones' rivals
# 2      and Fredo Corleone is sheltered by associate ...
# 3                                           he promises
# 4      promising Kay that he will make the business ...
# ...                                                 ...
# 1953   he is summoned to meet the President at the W...
# 1954                                         Sam Harris
# 1955   eventually vesting some of his valuable theat...
# 1956   culminating in the role of the U.S. President...
# 1957                                                NaN
#
#                                               wiki_plot  \
# 0     On the day of his only daughter's wedding, Vit...
# 1                                        the Tattaglias
# 2      Sonny speeds for her home but assassins ambus...
# 3                 before the heads of the Five Families
# 4      he insists Hagen relocate to Las Vegas and re...
# ...                                                 ...
# 1953   who presents him with a Congressional Gold Me...
# 1954   he finally interests a producer and they are ...
# 1955   he persuades his now struggling parents to jo...
# 1956   he performs a dance step down the stairs (whi...
# 1957                                                NaN
#
#                                               imdb_plot  \
# 0                                                   NaN
# 1      asks Vito for investment in the emerging drug...
# 2      the   Five Families  Five Families   erupt in...
# 3      to withdraw his opposition to their heroin bu...
# 4      Greene derides the Corleones as a fading powe...
# ...                                                 ...
# 1953   this happened several years previously). Coha...
# 1954   a young singer/dancer.  Cohan and his sister ...
# 1955   eventually vesting some of his valuable theat...
# 1956                         he joins a military parade
# 1957                                                NaN
#
#                                              Unnamed: 5  \
# 0                                                   NaN
# 1                              so he sends his enforcer
# 2      and   Fredo Corleone  Fredo Corleone   is she...
# 3      Michael returns home to a father saddened by ...
# 4      Michael sees Fredo falling under Greene's swa...
# ...                                                 ...
# 1953   recalling his early days on the stage. The fi...
# 1954   and soon The Four Cohans are performing succe...
# 1955                                                NaN
# 1956   where the soldiers are singing ""Over There""...
# 1957                                                NaN
#
#                                              Unnamed: 6  \
# 0                                                   NaN
# 1                                            Luca Brasi
# 2      Sonny speeds for her home but assassins ambus...
# 3      Vito decides to end the feuds. Realising that...
# 4                 Michael takes the reins of the family
# ...                                                 ...
# 1953   whilst his father is performing on the vaudev...
# 1954                                         Sam Harris
# 1955                                                NaN
# 1956                they jokingly invite him to join in
# 1957                                                NaN
#
#                                              Unnamed: 7  \
# 0                                                   NaN
# 1      to spy on them. The family then receives two ...
# 2                                                   NaN
# 3                                           he promises
# 4      promising Kay that he will make the business ...
# ...                                                 ...
# 1953   Cohan comes out of retirement to star as Pres...
# 1954   he finally interests a producer and they are ...
# 1955                                                NaN
# 1956                      which he does.  Cohan retires
# 1957                                                NaN
#
#                                              Unnamed: 8  \
# 0                                                   NaN
# 1      imparting that he ""sleeps with the fishes""....
# 2                                                   NaN
# 3                 before the heads of the Five Families
# 4      he insists Hagen relocate to Las Vegas and re...
# ...                                                 ...
# 1953   he is summoned to meet the President at the  ...
# 1954                           a young singer/dancer.
# 1955                                                NaN
# 1956             but returns to the stage several times
# 1957                                                NaN
#
#                                              Unnamed: 9  ... Unnamed: 324  \
# 0                                                   NaN  ...          NaN
# 1                                     so his eldest son  ...          NaN
# 2                                                   NaN  ...          NaN
# 3      to withdraw his opposition to their heroin bu...  ...          NaN
# 4      Greene derides the Corleones as a fading powe...  ...          NaN
# ...                                                 ...  ...          ...
# 1953   who presents him with a   Congressional Gold ...  ...          NaN
# 1954                                                NaN  ...          NaN
# 1955                                                NaN  ...          NaN
# 1956   culminating in the role of the U.S. President...  ...          NaN
# 1957                                                NaN  ...          NaN
#
#      Unnamed: 325 Unnamed: 326 Unnamed: 327 Unnamed: 328 Unnamed: 329  \
# 0             NaN          NaN          NaN          NaN          NaN
# 1             NaN          NaN          NaN          NaN          NaN
# 2             NaN          NaN          NaN          NaN          NaN
# 3             NaN          NaN          NaN          NaN          NaN
# 4             NaN          NaN          NaN          NaN          NaN
# ...           ...          ...          ...          ...          ...
# 1953          NaN          NaN          NaN          NaN          NaN
# 1954          NaN          NaN          NaN          NaN          NaN
# 1955          NaN          NaN          NaN          NaN          NaN
# 1956          NaN          NaN          NaN          NaN          NaN
# 1957          NaN          NaN          NaN          NaN          NaN
#
#      Unnamed: 330 Unnamed: 331 Unnamed: 332 Unnamed: 333
# 0             NaN          NaN          NaN          NaN
# 1             NaN          NaN          NaN          NaN
# 2             NaN          NaN          NaN          NaN
# 3             NaN          NaN          NaN          NaN
# 4             NaN          NaN          NaN          NaN
# ...           ...          ...          ...          ...
# 1953          NaN          NaN          NaN          NaN
# 1954          NaN          NaN          NaN          NaN
# 1955          NaN          NaN          NaN          NaN
# 1956          NaN          NaN          NaN          NaN
# 1957          NaN          NaN          NaN          NaN
#
# [1958 rows x 334 columns]

# %%
# Combine wiki_plot and imdb_plot into a single column
movies_df['plot'] = movies_df['wiki_plot'].astype(str) + "\n" + \
                 movies_df['imdb_plot'].astype(str)

# Inspect the new DataFrame
movies_df.head()
# Out:
#                                                 rank  \
# 0                                                  0
# 1                      Shortly before Christmas 1945
# 2           Despite a clampdown from the authorities
# 3                        Devastated by Sonny's death
# 4    With his father at the end of his career and...
#
#                                                title  \
# 0                                      The Godfather
# 1            drug baron Virgil ""The Turk"" Sollozzo
# 2   the Five Families erupt in open warfare and t...
# 3   Vito decides to end the feuds. Realising that...
# 4              Michael takes the reins of the family
#
#                                                genre  \
# 0                             [u' Crime', u' Drama']
# 1                    backed by the Corleones' rivals
# 2   and Fredo Corleone is sheltered by associate ...
# 3                                        he promises
# 4   promising Kay that he will make the business ...
#
#                                            wiki_plot  \
# 0  On the day of his only daughter's wedding, Vit...
# 1                                     the Tattaglias
# 2   Sonny speeds for her home but assassins ambus...
# 3              before the heads of the Five Families
# 4   he insists Hagen relocate to Las Vegas and re...
#
#                                            imdb_plot  \
# 0                                                NaN
# 1   asks Vito for investment in the emerging drug...
# 2   the   Five Families  Five Families   erupt in...
# 3   to withdraw his opposition to their heroin bu...
# 4   Greene derides the Corleones as a fading powe...
#
#                                           Unnamed: 5  \
# 0                                                NaN
# 1                           so he sends his enforcer
# 2   and   Fredo Corleone  Fredo Corleone   is she...
# 3   Michael returns home to a father saddened by ...
# 4   Michael sees Fredo falling under Greene's swa...
#
#                                           Unnamed: 6  \
# 0                                                NaN
# 1                                         Luca Brasi
# 2   Sonny speeds for her home but assassins ambus...
# 3   Vito decides to end the feuds. Realising that...
# 4              Michael takes the reins of the family
#
#                                           Unnamed: 7  \
# 0                                                NaN
# 1   to spy on them. The family then receives two ...
# 2                                                NaN
# 3                                        he promises
# 4   promising Kay that he will make the business ...
#
#                                           Unnamed: 8  \
# 0                                                NaN
# 1   imparting that he ""sleeps with the fishes""....
# 2                                                NaN
# 3              before the heads of the Five Families
# 4   he insists Hagen relocate to Las Vegas and re...
#
#                                           Unnamed: 9  ... Unnamed: 325  \
# 0                                                NaN  ...          NaN
# 1                                  so his eldest son  ...          NaN
# 2                                                NaN  ...          NaN
# 3   to withdraw his opposition to their heroin bu...  ...          NaN
# 4   Greene derides the Corleones as a fading powe...  ...          NaN
#
#   Unnamed: 326 Unnamed: 327 Unnamed: 328 Unnamed: 329 Unnamed: 330  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#   Unnamed: 331 Unnamed: 332 Unnamed: 333  \
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN
# 3          NaN          NaN          NaN
# 4          NaN          NaN          NaN
#
#                                                 plot
# 0  On the day of his only daughter's wedding, Vit...
# 1   the Tattaglias\n asks Vito for investment in ...
# 2   Sonny speeds for her home but assassins ambus...
# 3   before the heads of the Five Families\n to wi...
# 4   he insists Hagen relocate to Las Vegas and re...
#
# [5 rows x 335 columns]

# %%
import nltk
# Tokenize a paragraph into sentences and store in sent_tokenized
sent_tokenized = [sent for sent in nltk.sent_tokenize("""
                        Today (May 19, 2016) is his only daughter's wedding. 
                        Vito Corleone is the Godfather.
                        """)]

# Word Tokenize first sentence from sent_tokenized, save as words_tokenized
words_tokenized = [word for word in nltk.word_tokenize(sent_tokenized[0])]

# Remove tokens that do not contain any letters from words_tokenized
import re

filtered = [word for word in words_tokenized if re.search('[a-zA-Z]', word)]

# Display filtered words to observe words after tokenization
filtered
# Out:
# ['Today', 'May', 'is', 'his', 'only', 'daughter', "'s", 'wedding']

# %%
# Import the SnowballStemmer to perform stemming
from nltk.stem.snowball import SnowballStemmer

# Create an English language SnowballStemmer object
stemmer = SnowballStemmer("english")

# Print filtered to observe words without stemming
print("Without stemming: ", filtered)

# Stem the words from filtered and store in stemmed_words
stemmed_words = [stemmer.stem(word) for word in filtered]

# Print the stemmed_words to observe words after stemming
print("After stemming:   ", stemmed_words)
# Out:
# Without stemming:  ['Today', 'May', 'is', 'his', 'only', 'daughter', "'s", 'wedding']
# After stemming:    ['today', 'may', 'is', 'his', 'onli', 'daughter', "'s", 'wed']

# %%
# Define a function to perform both stemming and tokenization
def tokenize_and_stem(text):
    
    # Tokenize by sentence, then by word
    tokens = [y for x in nltk.sent_tokenize(text) for y in nltk.word_tokenize(x)]
    
    # Filter out raw tokens to remove noise
    filtered_tokens = [token for token in tokens if re.search('[a-zA-Z]', token)]
    
    # Stem the filtered_tokens
    stems = [stemmer.stem(word) for word in filtered_tokens]
    
    return stems

words_stemmed = tokenize_and_stem("Today (May 19, 2016) is his only daughter's wedding.")
print(words_stemmed)
# Out:
# ['today', 'may', 'is', 'his', 'onli', 'daughter', "'s", 'wed']

# %%
# Import TfidfVectorizer to create TF-IDF vectors
from sklearn.feature_extraction.text import TfidfVectorizer

# Instantiate TfidfVectorizer object with stopwords and tokenizer
# parameters for efficient processing of text
tfidf_vectorizer = TfidfVectorizer(max_df=0.8, max_features=200000,
                                 min_df=0.2, stop_words='english',
                                 use_idf=True, tokenizer=tokenize_and_stem,
                                 ngram_range=(1,3))

# %%
# Fit and transform the tfidf_vectorizer with the "plot" of each movie
# to create a vector representation of the plot summaries
tfidf_matrix = tfidf_vectorizer.fit_transform([x for x in movies_df["plot"]])

print(tfidf_matrix.shape)
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_extraction\text.py:404: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['abov', 'afterward', 'alon', 'alreadi', 'alway', 'ani', 'anoth', 'anyon', 'anyth', 'anywher', 'becam', 'becaus', 'becom', 'befor', 'besid', 'cri', 'describ', 'dure', 'els', 'elsewher', 'empti', 'everi', 'everyon', 'everyth', 'everywher', 'fifti', 'forti', 'henc', 'hereaft', 'herebi', 'howev', 'hundr', 'inde', 'mani', 'meanwhil', 'moreov', 'nobodi', 'noon', 'noth', 'nowher', 'onc', 'onli', 'otherwis', 'ourselv', 'perhap', 'pleas', 'sever', 'sinc', 'sincer', 'sixti', 'someon', 'someth', 'sometim', 'somewher', 'themselv', 'thenc', 'thereaft', 'therebi', 'therefor', 'togeth', 'twelv', 'twenti', 'veri', 'whatev', 'whenc', 'whenev', 'wherea', 'whereaft', 'wherebi', 'wherev', 'whi', 'yourselv'] not in stop_words.
#   warnings.warn(
# (1958, 2)

# %%
# Import k-means to perform clusters
from sklearn.cluster import KMeans

# Create a KMeans object with 5 clusters and save as km
km = KMeans(n_clusters=5)

# Fit the k-means object with tfidf_matrix
km.fit(tfidf_matrix)

clusters = km.labels_.tolist()

# Create a column cluster to denote the generated cluster for each movie
movies_df["cluster"] = clusters

# Display number of films per cluster (clusters from 0 to 4)
movies_df['cluster'].value_counts()
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_13796/1420607719.py:8: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   km.fit(tfidf_matrix)
# 1    1205
# 0     663
# 2      90
# Name: cluster, dtype: int64

# %%
# Import cosine_similarity to calculate similarity of movie plots
from sklearn.metrics.pairwise import cosine_similarity

# Calculate the similarity distance
similarity_distance = 1 - cosine_similarity(tfidf_matrix)

# %%
# Import matplotlib.pyplot for plotting graphs
import matplotlib.pyplot as plt

# Configure matplotlib to display the output inline
# %matplotlib inline

# Import modules necessary to plot dendrogram
from scipy.cluster.hierarchy import linkage, dendrogram

# %%
# Create mergings matrix 
mergings = linkage(similarity_distance, method='complete')

# Plot the dendrogram, using title as label column
dendrogram_ = dendrogram(mergings,
               labels=[x for x in movies_df["title"]],
               leaf_rotation=90,
               leaf_font_size=16,
)

# Adjust the plot
fig = plt.gcf()
_ = [lbl.set_color('r') for lbl in plt.gca().get_xmajorticklabels()]
fig.set_size_inches(108, 21)

# Show the plotted dendrogram
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\pylabtools.py:137: UserWarning: Glyph 151 (\x97) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\HP\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\pylabtools.py:137: UserWarning: Glyph 150 (\x96) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\HP\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\pylabtools.py:137: UserWarning: Glyph 146 (\x92) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
